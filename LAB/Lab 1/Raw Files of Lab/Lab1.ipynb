# %% [markdown]
# ### The following cell defines the "listen" function to simplify the listening avoiding the download. Don't modify it.

# %%
from IPython.display import HTML as __HTML
try:
    ___tups = __tups; del ___tups
except NameError:
    __tups = True; display(__HTML("<script>if(!window.stopOthersAdded){window.stopOthersAdded=!0;function stopOthers(currentAudio){document.querySelectorAll('audio').forEach(audio=>{if(audio!==currentAudio){audio.pause()}})}}</script>"))
def listen(src: str):
    display(__HTML(f"<audio controls onplay=\"stopOthers(this)\"><source src=\"{src}\">Your browser does not support the audio element. </audio>"))
# Out:
# <script>if(!window.stopOthersAdded){window.stopOthersAdded=!0;function stopOthers(currentAudio){document.querySelectorAll('audio').forEach(audio=>{if(audio!==currentAudio){audio.pause()}})}}</script>

# %% [markdown]
# # Lab 1
#
# Deliver only this notebook by exporting it to PDF (File -> Save and Export Notebook as -> PDF).
#
# ---

# %% [markdown]
# ## Team Members:
# + name1, surname1, student1 ID
# + name2, surname2, student2 ID
# + ...

# %% [markdown]
# ## 2.1 Using ffmpeg
# Use this cell to report the ffmpeg command strings used to create the 6 different files
# ```bash
# ffmpeg command 1
# .
# .
# .
# ffmpeg command 6
# ```
#
# ---

# %% [markdown]
# ## 2.2 Analyzing outputs

# %% [markdown]
# #### 1
# Use this cell to report one ffmpeg command string used to convert back **one of the 6 different files to wav**
# ```bash
# ffmpeg command
# ```

# %% [markdown]
# #### 2-3

# %%
import numpy as np
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt

# %%
sample_rate, samples_original = wav.read('dogs.wav') # load original file here
# complete with loading of other wav files

# %% [markdown]
# **Complete exercise 2.2.1 and 2.2.2 by adding code cells below here**
#
# Use as many cells as you wish

# %% [markdown]
# #### 4
# Report your comments about the listenings here. If you have any hindrance in doing so, report to the professor.
#
# + *comments on file 1*
# + *comments on file 5*
